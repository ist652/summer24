# %% [markdown]
# # TimeSeries Practice

# %% [markdown]
# #### The data set includes German totals of electricity consumption, wind power production, and solar power production
#
# Electricity production and consumption are reported as daily totals in gigawatt-hours (GWh). The columns of the data file are:
#
# - Date — The date (yyyy-mm-dd format)
# - Consumption — Electricity consumption in GWh
# - Wind — Wind power production in GWh
# - Solar — Solar power production in GWh
# - Wind+Solar — Sum of wind and solar power production in GWh
#
# Let us explore how electricity consumption and production varied over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})

# %% [markdown]
# A little about datetime

# %%
pd.to_datetime(['2/25/10', '8/6/17', '12/15/12'], format='%m/%d/%y')
# Out:
# DatetimeIndex(['2010-02-25', '2017-08-06', '2012-12-15'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# In pandas, a single point in time is represented as a Timestamp. We can use the to_datetime() function to create Timestamps from strings into variety of date/time formats.

# %%
pd.to_datetime('7/8/1952')

# '7/8/1952' is assumed to be month/day/year and is interpreted as July 8, 1952.
# Out:
# Timestamp('1952-07-08 00:00:00')

# %%
# we can use the dayfirst parameter to tell pandas to interpret the date as August 7, 1952.
pd.to_datetime('7/8/1952', dayfirst=True)
# Out:
# Timestamp('1952-08-07 00:00:00')

# %%
# If we supply a list or array of strings as input to to_datetime(), 
# it returns a sequence of date/time values in a DatetimeIndex object

pd.to_datetime(['2018-01-05', '7/8/1952', 'Oct 10, 1995'])
# Out:
# DatetimeIndex(['2018-01-05', '1952-07-08', '1995-10-10'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# In the DatetimeIndex above, the data type datetime64[ns] indicates that the underlying data is stored as 64-bit integers, in units of nanoseconds (ns). This data structure allows pandas to compactly store large sequences of date/time values and efficiently perform vectorized operations using NumPy datetime64 arrays.

# %%
#Any of the format codes from the strftime() and strptime() functions in Python's built-in datetime module can be used. 
#format codes %m (numeric month), %d (day of month), and %y (2-digit year) to specify the format.

pd.to_datetime(['2/25/10', '8/6/17', '12/15/12'], format='%m/%d/%y')
# Out:
# DatetimeIndex(['2010-02-25', '2017-08-06', '2012-12-15'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# #### Question 1
# #### Read in the "opsd_germany_daily.csv" file using pandas. What is the shape of the file?
# #### Show the first 3 rows
# #### What are the datatypes of the columns?

# %% [markdown]
# #### Question 2
# #### Set the Date column as the index.
# #### Add columns with year, month, and weekday name
# #### Output a sample

# %% [markdown]
# #### Question 3 - Time based indexing
# #### Select a slice of days, from '2014-01-20':'2014-01-22'
# #### Show rows for the entire month of February 2012

# %% [markdown]
# #### Question 4
# #### Create a line plot of the full time series of Germany's daily electricity consumption, using the DataFrame's plot() method.

# %% [markdown]
# #### Question 5
#
# #### Downsample the data to a weekly mean time series.
# #### Use the rolling() method to compute the 7-day rolling mean of our daily data. Use the center=True argument to label each window at its midpoint, so the rolling windows are:
#
# - 2006-01-01 to 2006-01-07 — labelled as 2006-01-04
# - 2006-01-02 to 2006-01-08 — labelled as 2006-01-05
#
# Execute this code
# Code - opsd_7d = opsd_daily[data_columns].rolling(7, center=True).mean()
#
#
# #### Compute a 365-day rolling mean electricity consumption. Use the variable name opsd_365d to conform with the plot below

# %%
#### Let us plot 

# Plot daily, 7-day rolling mean, and 365-day rolling mean time series
fig, ax = plt.subplots()
ax.plot(opsd_daily['Consumption'], marker='.', markersize=2, color='0.6',
linestyle='None', label='Daily')
ax.plot(opsd_7d['Consumption'], linewidth=2, label='7-d Rolling Mean')
ax.plot(opsd_365d['Consumption'], color='0.2', linewidth=3,
label='Trend (365-d Rolling Mean)')

# Set x-ticks to yearly interval and add legend and labels
ax.legend()
ax.set_xlabel('Year')
ax.set_ylabel('Consumption (GWh)')
ax.set_title('Trends in Electricity Consumption');


# What trends do you observe.
