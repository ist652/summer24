# %% [markdown]
# # Introduction to Folium Maps
#
# For more on this library see https://python-visualization.github.io/folium/latest/getting_started.html

# %%
# %matplotlib inline 

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import folium
import warnings
from IPython.display import display
#matplotlib.rcParams['figure.figsize'] = (20.0, 10.0) # larger figure size
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Folium with Leaflet.js
#
# Folium is a Python module wrapper for [Leaflet.js](http://leafletjs.com/), which uses [Open Street Maps](https://www.openstreetmap.us/). These are two, popular open source mapping libraries. Unlike Google maps API, its 100% free!
#
# You can use Folium to render maps in Python and put data on the maps. Here's how easy it is to bring up a map:

# %%
CENTER_US = (39.8333333,-98.585522)
london = (51.5074, -0.1278)
map = folium.Map(location=CENTER_US, zoom_start=4)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77e10d27f16831ae1f800e4ae0b44faf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77e10d27f16831ae1f800e4ae0b44faf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77e10d27f16831ae1f800e4ae0b44faf = L.map(
#                 &quot;map_77e10d27f16831ae1f800e4ae0b44faf&quot;,
#                 {
#                     center: [39.8333333, -98.585522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9e5f6091625a37b58e68dbf138655c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9e5f6091625a37b58e68dbf138655c4.addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# You can zoom right down to the street level and get a amazing detail. There are different maps you can use, as was covered in this week's reading.
#
# ### Mapping the student movie goers.
#
# Let's take the largest category of movie goers and map their whereabouts. We will first need to import a data set to give us a lat/lng for the `zip_code` we have in the dataframe. We could look this up with Google's geolookup API, but that's too slow as we will be making 100's of requests. It's better to have them stored already and merge them with `goers`!
#
# Let's import the zipcode database into a Pandas DataFrame, then merge it with the `goers` DataFrame:

# %%
# DATASET 1
goers = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/ist256/13-visualization/moviegoers.csv')
goers['age_group'] = ''
goers['age_group'][goers['age'] <=18] = 'Youth'
goers['age_group'][(goers['age'] >=19) & (goers['age'] <=55)] = 'Adult'
goers['age_group'][goers['age'] >=56] = 'Senior'

goers.sample(5)
# Out:
#      user_id  age gender occupation zip_code age_group
# 862      863   17      M    student    60089     Youth
# 429      430   38      M  scientist    98199     Adult
# 859      860   70      F    retired    48322    Senior
# 314      315   31      M   educator    18301     Adult
# 613      614   54      M   educator    80227     Adult

# %%
zipcodes = pd.read_csv('https://raw.githubusercontent.com/mafudge/datasets/master/zipcodes/free-zipcode-database-Primary.csv', dtype = {'Zipcode' :object})
data = goers.merge(zipcodes,  how ='inner', left_on='zip_code', right_on='Zipcode')
students = data[ data['occupation'] == 'student']
students.sample(3)
# Out:
#      user_id  age gender occupation zip_code age_group Zipcode ZipCodeType  \
# 89       621   17      M    student    60402     Youth   60402    STANDARD
# 221      188   42      M    student    29440     Adult   29440    STANDARD
# 142      347   18      M    student    90210     Youth   90210    STANDARD
#
#               City State LocationType    Lat    Long                Location  \
# 89          BERWYN    IL      PRIMARY  41.84  -87.79         NA-US-IL-BERWYN
# 221     GEORGETOWN    SC      PRIMARY  33.36  -79.29     NA-US-SC-GEORGETOWN
# 142  BEVERLY HILLS    CA      PRIMARY  34.09 -118.41  NA-US-CA-BEVERLY HILLS
#
#      Decommisioned  TaxReturnsFiled  EstimatedPopulation    TotalWages
# 89           False          27944.0              49199.0  9.207477e+08
# 221          False          11386.0              20441.0  3.091475e+08
# 142          False          10430.0              16984.0  1.586884e+09

# %% [markdown]
# Let's explain the code, as a Pandas refresher course:
#
# 1. in the first line I added `dtype = {'Zipcode' :object}` to force the `Zipcode` column to be of type `object` without that, it imports as type `int` and cannot match with the `goers` DataFrame.
# 1. the next line merges the two dataframes together where the `zip_code` in `goers` (on_left) matches `Zipcode` in `zipcodes` (on_right)
# 1. the result `data` is a combined DataFrame, which we then filter to only `student` occupations, sorting that in the `students` DataFrame
#
#
# ### Slapping those students on a map!
#
# We're ready to place the students on a map. It's easy:
#
# 1. For each row in the students dataframe:
# 1.   get the coordinates (lat /lng )
# 1.   make a `marker` with the coordinates
# 1.   add the marker to the map with `add_children()`
#
# Here we go!

# %%
for row in students.to_records():
    pos = (row['Lat'],row['Long'])
    message = f"{row['age']} year old {row['gender']}  {row['occupation']} from {row['City']},{row['State']}"
    marker = folium.Marker(location=pos, 
                    popup=message
                          )
    map.add_child(marker)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77e10d27f16831ae1f800e4ae0b44faf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77e10d27f16831ae1f800e4ae0b44faf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77e10d27f16831ae1f800e4ae0b44faf = L.map(
#                 &quot;map_77e10d27f16831ae1f800e4ae0b44faf&quot;,
#                 {
#                     center: [39.8333333, -98.585522],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9e5f6091625a37b58e68dbf138655c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9e5f6091625a37b58e68dbf138655c4.addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#             tile_layer_f9e5f6091625a37b58e68dbf138655c4.addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#             var marker_18efa2fd138a1d6f4a0c32c07ac67c5e = L.marker(
#                 [44.94, -93.1],
#                 {}
#             ).addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#         var popup_6d5f59b44d86c6bb5d3fa39e44f28374 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6329afeb4faa41b7a40701831a727f72 = $(`&lt;div id=&quot;html_6329afeb4faa41b7a40701831a727f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;13 year old F  student from SAINT PAUL,MN&lt;/div&gt;`)[0];
#                 popup_6d5f59b44d86c6bb5d3fa39e44f28374.setContent(html_6329afeb4faa41b7a40701831a727f72);
#
#
#
#         marker_18efa2fd138a1d6f4a0c32c07ac67c5e.bindPopup(popup_6d5f59b44d86c6bb5d3fa39e44f28374)
#         ;
#
#
#
#
#             var marker_70808f1554077bbafb74de48c550ce9d = L.marker(
#                 [44.9, -122.92],
#                 {}
#             ).addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#         var popup_8de9c6b9ad256ab56a60538c1914ceb9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_efa6f7357c7399aac027c2f835aa82c8 = $(`&lt;div id=&quot;html_efa6f7357c7399aac027c2f835aa82c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32 year old M  student from SALEM,OR&lt;/div&gt;`)[0];
#                 popup_8de9c6b9ad256ab56a60538c1914ceb9.setContent(html_efa6f7357c7399aac027c2f835aa82c8);
#
#
#
#         marker_70808f1554077bbafb74de48c550ce9d.bindPopup(popup_8de9c6b9ad256ab56a60538c1914ceb9)
#         ;
#
#
#
#
#             var marker_2b5d0d1dfb99c9e7d6d846ebfab3f2a6 = L.marker(
#                 [44.9, -122.92],
#                 {}
#             ).addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#         var popup_8b5cce3e562fdc2a8b3b656ceca00c94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a861ddd4261774a178d16d199b2b93dc = $(`&lt;div id=&quot;html_a861ddd4261774a178d16d199b2b93dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32 year old M  student from SALEM,OR&lt;/div&gt;`)[0];
#                 popup_8b5cce3e562fdc2a8b3b656ceca00c94.setContent(html_a861ddd4261774a178d16d199b2b93dc);
#
#
#
#         marker_2b5d0d1dfb99c9e7d6d846ebfab3f2a6.bindPopup(popup_8b5cce3e562fdc2a8b3b656ceca00c94)
#         ;
#
#
#
#
#             var marker_579c6a60ed95454196331bf599e23a06 = L.marker(
#                 [44.96, -93.26],
#                 {}
#             ).addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#         var popup_c9a988c42f5fb01ca818c38c2af50a5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0067857e73e7a396c8783c342ad6530c = $(`&lt;div id=&quot;html_0067857e73e7a396c8783c342ad6530c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;7 year old M  student from MINNEAPOLIS,MN&lt;/div&gt;`)[0];
#                 popup_c9a988c42f5fb01ca818c38c2af50a5a.setContent(html_0067857e73e7a396c8783c342ad6530c);
#
#
#
#         marker_579c6a60ed95454196331bf599e23a06.bindPopup(popup_c9a988c42f5fb01ca818c38c2af50a5a)
#         ;
#
#
#
#
#             var marker_33dbc1203cee762a374d38ce39b7985a = L.marker(
#                 [40.71, -73.99],
#                 {}
#             ).addTo(map_77e10d27f16831ae1f800e4ae0b44faf);
#
#
#         var popup_38e576328b5875d52a46527a95ca98e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2b98d0c5fb66e22e6abb6cc1ea1086e6 = $(`&lt;div id=&quot;html_2b98d0c5fb66e22e6abb6cc1ea1086e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;32 year old M  student from NEW YORK,NY&lt;/div&gt;`)[0];
#                 popup_38e576328b5875d52a46527a95ca98e2.setContent(html_2b98d0c5fb66e22e6abb6cc1ea1086e6);
#
#
#
#         marker_33dbc1203cee762a374d38ce39b7985a.bindPopup(popup_38e576328b5875d52a46527a95ca98e2)
#         ;

# %% [markdown]
# ## Interactive Maps
#
# Let's combine the map with an Interact drop down. That way we select an occupation first then display the pins for only that occupation.
#
# Here is an explanation of the code:
#
#     lines 4-5  : create a unique list of occupations from the data frame
#     lines 9-10 : create the map (must be re-created with each new selection
#     lines 11   : apply pandas filter to the data frame based selection
#     lines 12-18: loop over each row in the data frame, create a marker and add it to the map
#     lines 19   : display the map

# %%
## todo write code here!
from ipywidgets import interact_manual

occupations_list = list(data['occupation'].dropna().unique())
occupations_list.sort()

@interact_manual(occupation=occupations_list)
def main(occupation):
    CENTER_US = (39.8333333,-98.585522)
    map = folium.Map(location=CENTER_US, zoom_start=4)
    filter_df = data[ data['occupation'] == occupation ]
    for row in filter_df.to_records():
        pos = (row['Lat'],row['Long'])
        message = f"{row['age']} year old {row['gender']}  {row['occupation']} from {row['City']},{row['State']}"
        marker = folium.Marker(location=pos, 
                        popup=message
                              )
        map.add_child(marker)
    display(filter_df)
    display(map)
# Out:
# interactive(children=(Dropdown(description='occupation', options=('administrator', 'artist', 'doctor', 'educat…
