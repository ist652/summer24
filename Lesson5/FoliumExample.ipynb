# %%
# Install folium if necessary, and pandas to load our data.
#!pip install folium
import pandas as pd
import folium

#load and prepare the data.
csvpath = 'https://opendata.arcgis.com/datasets/c25921094a7d40e48302ad3a92fbed90_40.csv'
df = pd.read_csv(csvpath)
df.head()
# Out:
#             X          Y  OBJECTID                                 source  \
# 0 -118.292603  34.032567     23637  LA County ACWM, Farmers Markets, 2024
# 1 -118.217544  34.050933     23638  LA County ACWM, Farmers Markets, 2024
# 2 -118.129471  34.095499     23639  LA County ACWM, Farmers Markets, 2024
# 3 -118.157647  34.200186     23640  LA County ACWM, Farmers Markets, 2024
# 4 -118.255134  34.113560     23641  LA County ACWM, Farmers Markets, 2024
#
#     ext_id              cat1             cat2  cat3  org_name  \
# 0  3308267  Community Groups  Farmers Markets   NaN       NaN
# 1  3308268  Community Groups  Farmers Markets   NaN       NaN
# 2  3308269  Community Groups  Farmers Markets   NaN       NaN
# 3  3308270  Community Groups  Farmers Markets   NaN       NaN
# 4  3308271  Community Groups  Farmers Markets   NaN       NaN
#
#                           name  ...   longitude  email date_updated  \
# 0             Adams & Vermont   ... -118.292603    NaN          NaN
# 1      Adventist Health Wh Mem  ... -118.217544    NaN          NaN
# 2                     Alhambra  ... -118.129471    NaN          NaN
# 3                 Altadena CFM  ... -118.157647    NaN          NaN
# 4  Atwater Village              ... -118.255134    NaN          NaN
#
#   dis_status       POINT_X       POINT_Y OBJECTID_1  \
# 0        NaN  6.473017e+06  1.834361e+06          0
# 1        NaN  6.495773e+06  1.840987e+06          0
# 2        NaN  6.522472e+06  1.857159e+06          0
# 3        NaN  6.514002e+06  1.895269e+06          0
# 4        NaN  6.484444e+06  1.863805e+06          0
#
#                               allcats  nameUrlFriendly  isCounty
# 0  |Community Groups|Farmers Markets|              NaN         0
# 1  |Community Groups|Farmers Markets|              NaN         0
# 2  |Community Groups|Farmers Markets|              NaN         0
# 3  |Community Groups|Farmers Markets|              NaN         0
# 4  |Community Groups|Farmers Markets|              NaN         0
#
# [5 rows x 35 columns]

# %%
# removing rows with missing values in the 'hours' column using the dropna() method.
df = df.dropna(subset = ['hours'])
# After removing missing values, select specific columns 
df = df[['latitude','longitude','hours','phones','name','org_name']]
# fills missing values in the 'org_name' column with an empty string using the fillna() method.
df['org_name'] = df['org_name'].fillna('')
df.head()
# Out:
#     latitude   longitude                                     hours  phones  \
# 0  34.032567 -118.292603  Wednesday, Year Round, 2:00 pm - 5:30 pm     NaN
# 1  34.050933 -118.217544    Thursday, Year Round, 10:00am - 2:00pm     NaN
# 2  34.095499 -118.129471     Sunday, Year Round, 8:00 am - 1:00 pm     NaN
# 3  34.200186 -118.157647     Friday, Year Round, 4:00 pm - 8:00 pm     NaN
# 4  34.113560 -118.255134     Sunday, Year Round, 9:00 am - 2:00 pm     NaN
#
#                           name org_name
# 0             Adams & Vermont
# 1      Adventist Health Wh Mem
# 2                     Alhambra
# 3                 Altadena CFM
# 4  Atwater Village

# %% [markdown]
# #### Folium will create a map centered on the latitude and longitude in the first argument, and at the zoom scale you pass as the second

# %%
farmers_markets = folium.Map(location=[34,-118.2], zoom_start=10)

farmers_markets
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cd3b03184db2d540fc2682f59b84cba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cd3b03184db2d540fc2682f59b84cba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cd3b03184db2d540fc2682f59b84cba = L.map(
#                 &quot;map_4cd3b03184db2d540fc2682f59b84cba&quot;,
#                 {
#                     center: [34.0, -118.2],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f771a274558f119534c1243da32b74fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f771a274558f119534c1243da32b74fb.addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### You can loop the dataframe, we can use the latitude and longitude for each market to add a marker to their location.
# ### We can also add a floating tooltip that appears when you hover over a marker with the argument tooltip

# %%
# Loop through the dataframe to add markers according to the 
# latitude and longitude columns in each row.
# Add tooltips displaying the contents of the name column of each row.

for index, row in df.iterrows():

        folium.Marker(
            [row['latitude'],row['longitude']],
            tooltip = row['name']).add_to(farmers_markets)
        
farmers_markets
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cd3b03184db2d540fc2682f59b84cba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cd3b03184db2d540fc2682f59b84cba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cd3b03184db2d540fc2682f59b84cba = L.map(
#                 &quot;map_4cd3b03184db2d540fc2682f59b84cba&quot;,
#                 {
#                     center: [34.0, -118.2],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f771a274558f119534c1243da32b74fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f771a274558f119534c1243da32b74fb.addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             tile_layer_f771a274558f119534c1243da32b74fb.addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             var marker_193f488bb2a326e43d05fb022bda8df9 = L.marker(
#                 [34.03256707, -118.29260253],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_193f488bb2a326e43d05fb022bda8df9.bindTooltip(
#                 `&lt;div&gt;
#                      Adams &amp; Vermont
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_364e5089d55094ff77ef94eb07f48188 = L.marker(
#                 [34.05093349, -118.2175442],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_364e5089d55094ff77ef94eb07f48188.bindTooltip(
#                 `&lt;div&gt;
#                      Adventist Health Wh Mem
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dfb3ddc7cd94c97daf42856945642ab8 = L.marker(
#                 [34.09549878, -118.12947069],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_dfb3ddc7cd94c97daf42856945642ab8.bindTooltip(
#                 `&lt;div&gt;
#                      Alhambra
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee8ecd7a6e86c123366b56485bae0753 = L.marker(
#                 [34.200186, -118.15764717],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_ee8ecd7a6e86c123366b56485bae0753.bindTooltip(
#                 `&lt;div&gt;
#                      Altadena CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8da86296d0713c9fad938333b00ab284 = L.marker(
#                 [34.11356028, -118.25513409],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_8da86296d0713c9fad938333b00ab284.bindTooltip(
#                 `&lt;div&gt;
#                      Atwater Village
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa005109fa39767cdf0702c5045f730d = L.marker(
#                 [34.64709877, -118.16621429],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_aa005109fa39767cdf0702c5045f730d.bindTooltip(
#                 `&lt;div&gt;
#                      AV Winery CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdb9d9a2b54d570492d7abcf66f88e17 = L.marker(
#                 [34.05326381, -118.2529323],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_bdb9d9a2b54d570492d7abcf66f88e17.bindTooltip(
#                 `&lt;div&gt;
#                      Bank of America
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9f827ee3cf4e06c0ae1635065d57b05 = L.marker(
#                 [33.96826874, -118.14400158],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_e9f827ee3cf4e06c0ae1635065d57b05.bindTooltip(
#                 `&lt;div&gt;
#                      Bell Gardens CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9852ec963a3f43a0a2141a165df7f2e = L.marker(
#                 [33.88443912, -118.12380673],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_c9852ec963a3f43a0a2141a165df7f2e.bindTooltip(
#                 `&lt;div&gt;
#                      Bellflower
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7011fe29c9a2ec2c223a3ef40e6cd20b = L.marker(

# %% [markdown]
# 1. DataFrame Iteration: The code iterates through each row in the DataFrame to extract information about each farmers' market.
# 2. HTML Markup: The text variable contains HTML markup to format the information displayed in the marker popup.
# 3. Folium Marker Creation: The folium.Marker function is used to create markers on the map for each farmers' market.

# %%
# Add popups to each marker.  Use HTML code to artfully display
# hours, images, contact information, and the names of the 
# organizations that hosts the markets.

for index, row in df.iterrows():
        text = f"""
        <h3><b> {row.name} </b></h3><br>
        <p style="text-align:center;">{row.hours}</p>   
        <p style="text-align:center;">
        <img src="https://bit.ly/3iOISd4" alt="Farmer's Market Photo" style = "width:200px;height:200px;"> 
        <br>
        Image Courtesy of Kyle Neiber<br></p>
        <p style="text-align:center;color:blue">
        {row.org_name}<br>
        {row.phones}
        </p>
            """
        folium.Marker(
            [row['latitude'],row['longitude']],
           popup = folium.Popup(text, max_width = 400),
            tooltip = row['name']).add_to(farmers_markets)
        
farmers_markets
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cd3b03184db2d540fc2682f59b84cba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cd3b03184db2d540fc2682f59b84cba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cd3b03184db2d540fc2682f59b84cba = L.map(
#                 &quot;map_4cd3b03184db2d540fc2682f59b84cba&quot;,
#                 {
#                     center: [34.0, -118.2],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f771a274558f119534c1243da32b74fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f771a274558f119534c1243da32b74fb.addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             tile_layer_f771a274558f119534c1243da32b74fb.addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             var marker_193f488bb2a326e43d05fb022bda8df9 = L.marker(
#                 [34.03256707, -118.29260253],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_193f488bb2a326e43d05fb022bda8df9.bindTooltip(
#                 `&lt;div&gt;
#                      Adams &amp; Vermont
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_364e5089d55094ff77ef94eb07f48188 = L.marker(
#                 [34.05093349, -118.2175442],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_364e5089d55094ff77ef94eb07f48188.bindTooltip(
#                 `&lt;div&gt;
#                      Adventist Health Wh Mem
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dfb3ddc7cd94c97daf42856945642ab8 = L.marker(
#                 [34.09549878, -118.12947069],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_dfb3ddc7cd94c97daf42856945642ab8.bindTooltip(
#                 `&lt;div&gt;
#                      Alhambra
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee8ecd7a6e86c123366b56485bae0753 = L.marker(
#                 [34.200186, -118.15764717],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_ee8ecd7a6e86c123366b56485bae0753.bindTooltip(
#                 `&lt;div&gt;
#                      Altadena CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8da86296d0713c9fad938333b00ab284 = L.marker(
#                 [34.11356028, -118.25513409],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_8da86296d0713c9fad938333b00ab284.bindTooltip(
#                 `&lt;div&gt;
#                      Atwater Village
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aa005109fa39767cdf0702c5045f730d = L.marker(
#                 [34.64709877, -118.16621429],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_aa005109fa39767cdf0702c5045f730d.bindTooltip(
#                 `&lt;div&gt;
#                      AV Winery CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdb9d9a2b54d570492d7abcf66f88e17 = L.marker(
#                 [34.05326381, -118.2529323],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_bdb9d9a2b54d570492d7abcf66f88e17.bindTooltip(
#                 `&lt;div&gt;
#                      Bank of America
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9f827ee3cf4e06c0ae1635065d57b05 = L.marker(
#                 [33.96826874, -118.14400158],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_e9f827ee3cf4e06c0ae1635065d57b05.bindTooltip(
#                 `&lt;div&gt;
#                      Bell Gardens CFM
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c9852ec963a3f43a0a2141a165df7f2e = L.marker(
#                 [33.88443912, -118.12380673],
#                 {}
#             ).addTo(map_4cd3b03184db2d540fc2682f59b84cba);
#
#
#             marker_c9852ec963a3f43a0a2141a165df7f2e.bindTooltip(
#                 `&lt;div&gt;
#                      Bellflower
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7011fe29c9a2ec2c223a3ef40e6cd20b = L.marker(

# %% [markdown]
# ##### Additional Sources
#
# ##### Folium on Github: https://github.com/python-visualization/folium
#
# ##### City of Los Angeles Datahub: https://geohub.lacity.org/datasets/
#
# ##### Python Visualization: https://python-visualization.github.io/folium/quickstart.html
